# %% [markdown]
# # Start ML

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("kaggle_data.csv")
df
# Out:
#    Unnamed: 0       team_1       team_2        stage  Winner_toss  \
# 0     Match_1    Australia  SouthAfrica  Group_stage    Australia
# 1     Match_2      England      Windies  Group_stage      England
# 2     Match_3     Srilanka   Bangladesh  Group_stage     Srilanka
# 3     Match_4     Pakistan        India  Group_stage     Pakistan
# 4     Match_5  Afghanistan     Scotland  Group_stage  Afghanistan
# 5     Match_6  SouthAfrica      Windies  Group_stage  SouthAfrica
# 6     Match_7     Pakistan  New_Zealand  Group_stage     Pakistan
# 7     Match_8      England   Bangladesh  Group_stage   Bangladesh
# 8     Match_9      Namibia     ScotLand  Group_stage      Namibia
# 9    Match_10    Australia     Srilanka  Group_stage    Australia
# 10   Match_11      Windies   Bangladesh  Group_stage   Bangladesh
# 11   Match_12     Pakistan  Afghanistan  Group_stage  Afghanistan
# 12   Match_13  SouthAfrica     Srilanka  Group_stage  SouthAfrica
# ...

# %%
df.head(7)
# Out:
#   Unnamed: 0       team_1       team_2        stage  Winner_toss  \
# 0    Match_1    Australia  SouthAfrica  Group_stage    Australia
# 1    Match_2      England      Windies  Group_stage      England
# 2    Match_3     Srilanka   Bangladesh  Group_stage     Srilanka
# 3    Match_4     Pakistan        India  Group_stage     Pakistan
# 4    Match_5  Afghanistan     Scotland  Group_stage  Afghanistan
# 5    Match_6  SouthAfrica      Windies  Group_stage  SouthAfrica
# 6    Match_7     Pakistan  New_Zealand  Group_stage     Pakistan
#
#   Toss_descision       time      venue  avg_temperature        best_bowler  \
# 0       Fielding  afternoon  Abu_Dhabi               30     Josh_Hazlewood
# 1       Fielding    evening      Dubai               33        Adil_Rashid
# 2       Fielding  afternoon    Sharjah               34   Shakib_al_Hassan
# 3       Fielding    evening      Dubai               34       Shaheen_shah
# ...

# %%
df.tail()
# Out:
#    Unnamed: 0       team_1       team_2        stage  Winner_toss  \
# 28   Match_29     Pakistan     ScotLand  Group_stage     Pakistan
# 29   Match_30        India      Namibia  Group_stage        India
# 30   Match_31  New_Zealand      England   Semi_Final  New_Zealand
# 31   Match_32    Australia     Pakistan   Semi_Final    Australia
# 32   Match_33    Australia  New_Zealand        Final    Australia
#
#    Toss_descision     time      venue  avg_temperature       best_bowler  ...  \
# 28        Batting  evening    Sharjah               27       Shadab_Khan  ...
# 29       Fielding  evening      Dubai               28   Ravindra_Jadeja  ...
# 30       Fielding  evening  Abu_Dhabi               28  Liam_Livingstone  ...
# 31       Fielding  evening      Dubai               29       Shadab_Khan  ...
# 32       Fielding  evening      Dubai               26    Josh_Hazlewood  ...
#
#    best_bowler_country      best_batter  batting_hand  high_indvidual_scores  \
# ...

# %%
df.shape
# Out:
# (33, 24)

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
 df[["Winner"]]
# Out:
#          Winner
# 0     Australia
# 1       England
# 2      Srilanka
# 3      Pakistan
# 4   Afghanistan
# 5   SouthAfrica
# 6      Pakistan
# 7       England
# 8       Namibia
# 9     Australia
# 10      Windies
# 11     Pakistan
# 12  SouthAfrica
# 13      England
# 14  Afghanistan
# 15  New_Zealand
# 16      England
# 17  SouthAfrica
# 18     Pakistan
# 19  New_Zealand
# 20        India
# 21    Australia
# 22     Srilanka
# 23  New_Zealand
# 24        India
# 25    Australia
# 26  SouthAfrica
# 27  New_Zealand
# 28     Pakistan
# 29        India
# 30  New_Zealand
# 31    Australia
# 32    Australia

# %%
df.iloc[0:3]
# Out:
#   Unnamed: 0     team_1       team_2        stage Winner_toss Toss_descision  \
# 0    Match_1  Australia  SouthAfrica  Group_stage   Australia       Fielding
# 1    Match_2    England      Windies  Group_stage     England       Fielding
# 2    Match_3   Srilanka   Bangladesh  Group_stage    Srilanka       Fielding
#
#         time      venue  avg_temperature       best_bowler  ...  \
# 0  afternoon  Abu_Dhabi               30    Josh_Hazlewood  ...
# 1    evening      Dubai               33       Adil_Rashid  ...
# 2  afternoon    Sharjah               34  Shakib_al_Hassan  ...
#
#   best_bowler_country       best_batter  batting_hand  high_indvidual_scores  \
# 0           Australia     Aiden_Markram         Right                     40
# 1             England       Jos_Buttler         Right                     24
# 2          Bangladesh  Charith_Asalanka          Left                     80
#
#   strike_rate best_batter_team target  target_achieved  Player_of_the_match  \
# ...

# %%
df.loc[0:3]
# Out:
#   Unnamed: 0     team_1       team_2        stage Winner_toss Toss_descision  \
# 0    Match_1  Australia  SouthAfrica  Group_stage   Australia       Fielding
# 1    Match_2    England      Windies  Group_stage     England       Fielding
# 2    Match_3   Srilanka   Bangladesh  Group_stage    Srilanka       Fielding
# 3    Match_4   Pakistan        India  Group_stage    Pakistan       Fielding
#
#         time      venue  avg_temperature       best_bowler  ...  \
# 0  afternoon  Abu_Dhabi               30    Josh_Hazlewood  ...
# 1    evening      Dubai               33       Adil_Rashid  ...
# 2  afternoon    Sharjah               34  Shakib_al_Hassan  ...
# 3    evening      Dubai               34      Shaheen_shah  ...
#
#   best_bowler_country       best_batter  batting_hand  high_indvidual_scores  \
# 0           Australia     Aiden_Markram         Right                     40
# 1             England       Jos_Buttler         Right                     24
# ...

# %%
help(df.iloc)
# Out:
# Help on _iLocIndexer in module pandas.core.indexing object:
#
# class _iLocIndexer(_LocationIndexer)
#  |  Purely integer-location based indexing for selection by position.
#  |
#  |  ``.iloc[]`` is primarily integer position based (from ``0`` to
#  |  ``length-1`` of the axis), but may also be used with a boolean
#  |  array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - An integer, e.g. ``5``.
#  |  - A list or array of integers, e.g. ``[4, 3, 0]``.
#  |  - A slice object with ints, e.g. ``1:7``.
#  |  - A boolean array.
#  |  - A ``callable`` function with one argument (the calling Series or
#  |    DataFrame) and that returns valid output for indexing (one of the above).
#  |    This is useful in method chains, when you don't have a reference to the
#  |    calling object, but would like to base your selection on some value.
#  |
#  |  ``.iloc`` will raise ``IndexError`` if a requested indexer is
#  |  out-of-bounds, except *slice* indexers which allow out-of-bounds
# ...

# %%
df.iloc[[0, 3], [1, 3]]
# Out:
#       team_1        stage
# 0  Australia  Group_stage
# 3   Pakistan  Group_stage

# %%
help(df.loc)
# Out:
# Help on _LocIndexer in module pandas.core.indexing object:
#
# class _LocIndexer(_LocationIndexer)
#  |  Access a group of rows and columns by label(s) or a boolean array.
#  |
#  |  ``.loc[]`` is primarily label based, but may also be used with a
#  |  boolean array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - A single label, e.g. ``5`` or ``'a'``, (note that ``5`` is
#  |    interpreted as a *label* of the index, and **never** as an
#  |    integer position along the index).
#  |  - A list or array of labels, e.g. ``['a', 'b', 'c']``.
#  |  - A slice object with labels, e.g. ``'a':'f'``.
#  |
#  |    .. warning:: Note that contrary to usual python slices, **both** the
#  |        start and the stop are included
#  |
#  |  - A boolean array of the same length as the axis being sliced,
#  |    e.g. ``[True, False, True]``.
#  |  - A ``callable`` function with one argument (the calling Series or
#  |    DataFrame) and that returns valid output for indexing (one of the above)
#  |
# ...
